# %%
import pandas as pd

# Define relevant clinical significance terms
clinically_relevant_terms = {'Pathogenic', 'Likely_pathogenic', 'Risk_factor', 'association'}

vcf_file = 'clinically_relevant_snps_filtered.txt'
clinically_relevant_snps = []

with open(vcf_file, 'r') as file:
    for line in file:
        if line.startswith('#'):
            continue
        parts = line.strip().split('\t')
        chrom, pos, rsid, ref, alt, info, genotype = parts[0], parts[1], parts[2], parts[3], parts[4], parts[7], parts[9]
        
        info_fields = {kv.split('=')[0]: kv.split('=')[1] for kv in info.split(';') if '=' in kv}
        clinical_significance = info_fields.get('CLNSIG', 'unknown')

        # Check if clinical significance is relevant
        if clinical_significance in clinically_relevant_terms:
            disease = info_fields.get('CLNDN', 'not_specified')
            gene = info_fields.get('GENEINFO', 'not_specified')
            clinically_relevant_snps.append([chrom, pos, rsid, ref, alt, genotype, clinical_significance, disease, gene])
# Create DataFrame
columns = ['Chromosome', 'Position', 'rsID', 'REF', 'ALT', 'Genotype', 'Clinical_Significance', 'Disease', 'Gene']
clinical_df = pd.DataFrame(clinically_relevant_snps, columns=columns)

# Save results
clinical_df.to_csv('clinically_relevant_snps.csv', sep='\t', index=False)

# Display DataFrame
print(clinical_df)
# Out:
#    Chromosome   Position               rsID REF ALT Genotype  \
# 0           1   31349647    rs2491132;12756   C   T      0/1
# 1           2   33682737   rs2124437;236028   G   T      0/1
# 2           2  103092513  rs1468788;1120031   C   T      0/1
# 3           2  103125984  rs4851608;1120028   C   T      0/1
# 4           4    9966380     rs7442295;4593   A   G      0/1
# 5           4  145460230  rs13147758;870129   A   G      0/1
# 6           4  145480780   rs1828591;870131   A   G      0/1
# 7           4  145486389  rs13118928;870130   A   G      0/1
# 8           5  167845791    rs17070145;1213   C   T      0/1
# 9           6   31794592   rs2763979;694519   C   T      0/1
# 10          7   28532464  rs4722804;1691115   G   T      0/1
# 11          8   61452046  rs2272620;1691117   A   G      0/1
# 12         10   96797470  rs1934953;1693596   C   T      0/1
# 13         15   28365618    rs12913832;4745   A   G      0/1
# 14         15   28530182     rs1667394;4743   C   T      0/1
# 15         16   16171148   rs4148353;126858   G   T      0/1
# 16         16   20365654  rs13333226;219224   A   G      0/1
# 17         17   40688291   i6015336;3759435   A   T      0/1
# 18         17   63133674   i6031250;3249550   C   T      0/1
# 19         19   10218030   rs1551570;180725   C   T      0/1
#
#    Clinical_Significance                                            Disease  \
# 0            association                          Obesity,_association_with
# 1            association                      Lip_and_oral_cavity_carcinoma
# 2            association                        Ascending_aortic_dissection
# 3            association                        Ascending_aortic_dissection
# 4            association  Uric_acid_concentration,_serum,_quantitative_t...
# 5            association  Chronic_obstructive_pulmonary_disease|Chronic_...
# 6            association  Chronic_obstructive_pulmonary_disease|Chronic_...
# 7            association  Chronic_obstructive_pulmonary_disease|Chronic_...
# 8            association                    Memory_quantitative_trait_locus
# 9            association              Chronic_obstructive_pulmonary_disease
# 10           association  Vascular_endothelial_growth_factor_(VEGF)_inhi...
# 11           association  Vascular_endothelial_growth_factor_(VEGF)_inhi...
# 12           association  Pulmonary_disease,_chronic_obstructive,_suscep...
# 13           association    SKIN/HAIR/EYE_PIGMENTATION_1,_BLUE/NONBLUE_EYES
# 14           association    SKIN/HAIR/EYE_PIGMENTATION_1,_BLUE/NONBLUE_EYES
# 15           association                          Familial_cancer_of_breast
# 16           association                             Essential_hypertension
# 17            Pathogenic  Mucopolysaccharidosis,_MPS-III-B|Charcot-Marie...
# 18     Likely_pathogenic                                  Retinal_dystrophy
# 19           association                           Cataplexy_and_narcolepsy
#
#                                  Gene
# 0                           SDC3:9672
# 1                       RASGRP3:25780
# 2                       SLC9A4:389015
# 3                       SLC9A4:389015
# 4                        SLC2A9:56606
# 5                          HHIP:64399
# 6                          HHIP:64399
# 7                          HHIP:64399
# 8                          WWC1:23286
# 9                         HSPA1B:3304
# 10                         CREB5:9586
# 11                         RAB2A:5862
# 12                        CYP2C8:1558
# 13  HERC2:8924|LOC128772394:128772394
# 14                         HERC2:8924
# 15                         ABCC1:4363
# 16                          UMOD:7369
# 17  NAGLU:4669|LOC130060903:130060903
# 18   RGS9:8787|LOC130061461:130061461
# 19      PPAN:56342|PPAN-P2RY11:692312

# %%
clinical_df['Genotype_Interpretation'] = clinical_df.apply(
    lambda row: 'Carrier (possible risk)' if row['Clinical_Significance'].lower() in ['pathogenic', 'likely_pathogenic'] 
                else 'Increased risk/association', axis=1)

# %%
clinical_df
# Out:
#    Chromosome   Position               rsID REF ALT Genotype  \
# 0           1   31349647    rs2491132;12756   C   T      0/1
# 1           2   33682737   rs2124437;236028   G   T      0/1
# 2           2  103092513  rs1468788;1120031   C   T      0/1
# 3           2  103125984  rs4851608;1120028   C   T      0/1
# 4           4    9966380     rs7442295;4593   A   G      0/1
# 5           4  145460230  rs13147758;870129   A   G      0/1
# 6           4  145480780   rs1828591;870131   A   G      0/1
# 7           4  145486389  rs13118928;870130   A   G      0/1
# 8           5  167845791    rs17070145;1213   C   T      0/1
# 9           6   31794592   rs2763979;694519   C   T      0/1
# 10          7   28532464  rs4722804;1691115   G   T      0/1
# 11          8   61452046  rs2272620;1691117   A   G      0/1
# 12         10   96797470  rs1934953;1693596   C   T      0/1
# 13         15   28365618    rs12913832;4745   A   G      0/1
# 14         15   28530182     rs1667394;4743   C   T      0/1
# 15         16   16171148   rs4148353;126858   G   T      0/1
# 16         16   20365654  rs13333226;219224   A   G      0/1
# 17         17   40688291   i6015336;3759435   A   T      0/1
# 18         17   63133674   i6031250;3249550   C   T      0/1
# 19         19   10218030   rs1551570;180725   C   T      0/1
#
#    Clinical_Significance                                            Disease  \
# 0            association                          Obesity,_association_with
# 1            association                      Lip_and_oral_cavity_carcinoma
# 2            association                        Ascending_aortic_dissection
# 3            association                        Ascending_aortic_dissection
# 4            association  Uric_acid_concentration,_serum,_quantitative_t...
# 5            association  Chronic_obstructive_pulmonary_disease|Chronic_...
# 6            association  Chronic_obstructive_pulmonary_disease|Chronic_...
# 7            association  Chronic_obstructive_pulmonary_disease|Chronic_...
# 8            association                    Memory_quantitative_trait_locus
# 9            association              Chronic_obstructive_pulmonary_disease
# 10           association  Vascular_endothelial_growth_factor_(VEGF)_inhi...
# 11           association  Vascular_endothelial_growth_factor_(VEGF)_inhi...
# 12           association  Pulmonary_disease,_chronic_obstructive,_suscep...
# 13           association    SKIN/HAIR/EYE_PIGMENTATION_1,_BLUE/NONBLUE_EYES
# 14           association    SKIN/HAIR/EYE_PIGMENTATION_1,_BLUE/NONBLUE_EYES
# 15           association                          Familial_cancer_of_breast
# 16           association                             Essential_hypertension
# 17            Pathogenic  Mucopolysaccharidosis,_MPS-III-B|Charcot-Marie...
# 18     Likely_pathogenic                                  Retinal_dystrophy
# 19           association                           Cataplexy_and_narcolepsy
#
#                                  Gene     Genotype_Interpretation
# 0                           SDC3:9672  Increased risk/association
# 1                       RASGRP3:25780  Increased risk/association
# 2                       SLC9A4:389015  Increased risk/association
# 3                       SLC9A4:389015  Increased risk/association
# 4                        SLC2A9:56606  Increased risk/association
# 5                          HHIP:64399  Increased risk/association
# 6                          HHIP:64399  Increased risk/association
# 7                          HHIP:64399  Increased risk/association
# 8                          WWC1:23286  Increased risk/association
# 9                         HSPA1B:3304  Increased risk/association
# 10                         CREB5:9586  Increased risk/association
# 11                         RAB2A:5862  Increased risk/association
# 12                        CYP2C8:1558  Increased risk/association
# 13  HERC2:8924|LOC128772394:128772394  Increased risk/association
# 14                         HERC2:8924  Increased risk/association
# 15                         ABCC1:4363  Increased risk/association
# 16                          UMOD:7369  Increased risk/association
# 17  NAGLU:4669|LOC130060903:130060903     Carrier (possible risk)
# 18   RGS9:8787|LOC130061461:130061461     Carrier (possible risk)
# 19      PPAN:56342|PPAN-P2RY11:692312  Increased risk/association
